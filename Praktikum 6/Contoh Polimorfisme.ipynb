# %%
def tambah (a, b):
    return a + b

print(tambah(2, 3))
print(tambah("Hello", " AI"))
# Out:
# 5
# Hello AI

# %%
def kali (c, d):
    return c * d

print(kali(2,3))
print(kali("Hello ", 3))
# Out:
# 6
# Hello Hello Hello
